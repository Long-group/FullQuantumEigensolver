# %%
import scipy as sp
from openfermionpyscf import run_pyscf
from openfermion import *
from pyscf import mp, cc, fci
import numpy as np
import json

# %% [markdown]
# # 1. Data input and parameter setting

# %%
# read the molecule data
Molecules_Data = json.load(open('Molecules_Data.json', 'r'))
Molecules_Data
# Out:
# {'AlCl3': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '2.0875', '0.0000'],
#    ['1.8078', '-1.0437', '0.0000'],
#    ['-1.8078', '-1.0437', '0.0000']],
#   'Molecules': ['Al1', 'Cl2', 'Cl3', 'Cl4'],
#   'Name': 'AlCl3',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['1.5089', '-1.4425', '0.0000'],
#    ['0.4948', '2.0280', '0.0000'],
#    ['-2.0037', '-0.5855', '0.0000']]},
#  'AlF3': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '1.6390', '0.0000'],
#    ['1.4194', '-0.8195', '0.0000'],
#    ['-1.4194', '-0.8195', '0.0000']],
#   'Molecules': ['Al1', 'F2', 'F3', 'F4'],
#   'Name': 'AlF3',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['1.5142', '0.6272', '0.0000'],
#    ['-1.3003', '0.9978', '0.0000'],
#    ['-0.2139', '-1.6250', '0.0000']]},
#  'AlH3': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '1.5890', '0.0000'],
#    ['1.3761', '-0.7945', '0.0000'],
#    ['-1.3761', '-0.7945', '0.0000']],
#   'Molecules': ['Al1', 'H2', 'H3', 'H4'],
#   'Name': 'AlH3',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['1.4436', '0.6640', '0.0000'],
#    ['-1.2968', '0.9182', '0.0000'],
#    ['-0.1468', '-1.5822', '0.0000']]},
#  'B2H6': {'Internal': [['0.8843', '0.0000', '0.0000'],
#    ['-0.8843', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '0.9759'],
#    ['0.0000', '0.0000', '-0.9759'],
#    ['1.4627', '1.0408', '0.0000'],
#    ['1.4627', '-1.0408', '0.0000'],
#    ['-1.4627', '1.0408', '0.0000'],
#    ['-1.4627', '-1.0408', '0.0000']],
#   'Molecules': ['B1', 'B2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8'],
#   'Name': 'B2H6',
#   'Principal': [['0.8843', '0.0000', '0.0000'],
#    ['-0.8843', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '0.9759'],
#    ['0.0000', '0.0000', '-0.9759'],
#    ['1.4627', '1.0408', '0.0000'],
#    ['1.4627', '-1.0408', '0.0000'],
#    ['-1.4627', '1.0408', '0.0000'],
#    ['-1.4627', '-1.0408', '0.0000']]},
#  'BF3': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '1.3177', '0.0000'],
#    ['1.1412', '-0.6589', '0.0000'],
#    ['-1.1412', '-0.6589', '0.0000']],
#   'Molecules': ['B1', 'F2', 'F3', 'F4'],
#   'Name': 'BF3',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['1.2937', '-0.2506', '0.0000'],
#    ['-0.4299', '1.2457', '0.0000'],
#    ['-0.8639', '-0.9951', '0.0000']]},
#  'BN': {'Internal': [['0.0000', '0.0000', '-0.7730'],
#    ['0.0000', '0.0000', '0.5521']],
#   'Molecules': ['B1', 'N2'],
#   'Name': 'BN'},
#  'BeCl2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.8026'],
#    ['0.0000', '0.0000', '-1.8026']],
#   'Molecules': ['Be1', 'Cl2', 'Cl3'],
#   'Name': 'BeCl2'},
#  'BeH2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.3300'],
#    ['0.0000', '0.0000', '-1.3300']],
#   'Molecules': ['Be1', 'H2', 'H3'],
#   'Name': 'BeH2'},
#  'BeO': {'Internal': [['0.0000', '0.0000', '-0.8853'],
#    ['0.0000', '0.0000', '0.4426']],
#   'Molecules': ['Be1', 'O2'],
#   'Name': 'BeO'},
#  'BeS': {'Internal': [['0.0000', '0.0000', '-1.4002'],
#    ['0.0000', '0.0000', '0.3500']],
#   'Molecules': ['Be1', 'S2'],
#   'Name': 'BeS',
#   'Principal': [['-1.4002', '0.0000', '0.0000'],
#    ['0.3500', '0.0000', '0.0000']]},
#  'CCl4': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['1.0349', '1.0349', '1.0349'],
#    ['-1.0349', '-1.0349', '1.0349'],
#    ['-1.0349', '1.0349', '-1.0349'],
#    ['1.0349', '-1.0349', '-1.0349']],
#   'Molecules': ['C1', 'Cl2', 'Cl3', 'Cl4', 'Cl5'],
#   'Name': 'CCl4',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['1.4635', '0.0000', '1.0349'],
#    ['-1.4635', '0.0000', '1.0349'],
#    ['0.0000', '-1.4635', '-1.0349'],
#    ['0.0000', '1.4635', '-1.0349']]},
#  'CF4': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.7675', '0.7675', '0.7675'],
#    ['-0.7675', '-0.7675', '0.7675'],
#    ['-0.7675', '0.7675', '-0.7675'],
#    ['0.7675', '-0.7675', '-0.7675']],
#   'Molecules': ['C1', 'F2', 'F3', 'F4', 'F5'],
#   'Name': 'CF4',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['0.7675', '0.6834', '0.8433'],
#    ['0.7675', '-0.6834', '-0.8433'],
#    ['-0.7675', '0.8433', '-0.6834'],
#    ['-0.7675', '-0.8433', '0.6834']]},
#  'CH4': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.6312', '0.6312', '0.6312'],
#    ['-0.6312', '-0.6312', '0.6312'],
#    ['-0.6312', '0.6312', '-0.6312'],
#    ['0.6312', '-0.6312', '-0.6312']],
#   'Molecules': ['C1', 'H2', 'H3', 'H4', 'H5'],
#   'Name': 'CH4',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['0.9197', '0.5526', '-0.2095'],
#    ['-0.2596', '0.1116', '1.0561'],
#    ['-0.8109', '0.3942', '-0.6183'],
#    ['0.1508', '-1.0585', '-0.2283']]},
#  'CO2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.1692'],
#    ['0.0000', '0.0000', '-1.1692']],
#   'Molecules': ['C1', 'O2', 'O3'],
#   'Name': 'CO2'},
#  'CS2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.5632'],
#    ['0.0000', '0.0000', '-1.5632']],
#   'Molecules': ['C1', 'S2', 'S3'],
#   'Name': 'CS2',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['1.5632', '0.0000', '0.0000'],
#    ['-1.5632', '0.0000', '0.0000']]},
#  'Cl2': {'Internal': [['0.0000', '0.0000', '1.0213'],
#    ['0.0000', '0.0000', '-1.0213']],
#   'Molecules': ['Cl1', 'Cl2'],
#   'Name': 'Cl2'},
#  'ClF3': {'Internal': [['0.0000', '0.0000', '0.3727'],
#    ['0.0000', '0.0000', '-1.2778'],
#    ['0.0000', '1.7268', '0.2869'],
#    ['0.0000', '-1.7268', '0.2869']],
#   'Molecules': ['Cl1', 'F2', 'F3', 'F4'],
#   'Name': 'ClF3',
#   'Principal': [['0.0000', '0.3727', '0.0000'],
#    ['0.0000', '-1.2778', '0.0000'],
#    ['1.7268', '0.2869', '0.0000'],
#    ['-1.7268', '0.2869', '0.0000']]},
#  'F2': {'Internal': [['0.0000', '0.0000', '0.7017'],
#    ['0.0000', '0.0000', '-0.7017']],
#   'Molecules': ['F1', 'F2'],
#   'Name': 'F2'},
#  'H2': {'Internal': [['0.0000', '0.0000', '0.3714'],
#    ['0.0000', '0.0000', '-0.3714']],
#   'Molecules': ['H1', 'H2'],
#   'Name': 'H2'},
#  'H2O': {'Internal': [['0.0000', '0.0000', '0.1197'],
#    ['0.0000', '0.7616', '-0.4786'],
#    ['0.0000', '-0.7616', '-0.4786']],
#   'Molecules': ['O1', 'H2', 'H3'],
#   'Name': 'H2O',
#   'Principal': [['0.0000', '0.1197', '0.0000'],
#    ['0.7616', '-0.4786', '0.0000'],
#    ['-0.7616', '-0.4786', '0.0000']]},
#  'H2S': {'Internal': [['0.0000', '0.0000', '0.1034'],
#    ['0.0000', '0.9770', '-0.8275'],
#    ['0.0000', '-0.9770', '-0.8275']],
#   'Molecules': ['S1', 'H2', 'H3'],
#   'Name': 'H2S',
#   'Principal': [['0.0000', '0.1034', '0.0000'],
#    ['0.9770', '-0.8275', '0.0000'],
#    ['-0.9770', '-0.8275', '0.0000']]},
#  'HCl': {'Internal': [['0.0000', '0.0000', '-1.2180'],
#    ['0.0000', '0.0000', '0.0716']],
#   'Molecules': ['H1', 'Cl2'],
#   'Name': 'HCl'},
#  'HF': {'Internal': [['0.0000', '0.0000', '0.0934'],
#    ['0.0000', '0.0000', '-0.8404']],
#   'Molecules': ['F1', 'H2'],
#   'Name': 'HF'},
#  'Li2O': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.6268'],
#    ['0.0000', '0.0000', '-1.6268']],
#   'Molecules': ['O1', 'Li2', 'Li3'],
#   'Name': 'Li2O'},
#  'Li2S': {'Internal': [['0.0000', '0.0000', '0.2576'],
#    ['0.0000', '1.8800', '-0.6868'],
#    ['0.0000', '-1.8800', '-0.6868']],
#   'Molecules': ['S1', 'Li2', 'Li3'],
#   'Name': 'Li2S',
#   'Principal': [['0.0000', '0.2576', '0.0000'],
#    ['1.8800', '-0.6868', '0.0000'],
#    ['-1.8800', '-0.6868', '0.0000']]},
#  'Li3N': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '1.7483', '0.0000'],
#    ['1.5141', '-0.8741', '0.0000'],
#    ['-1.5141', '-0.8741', '0.0000']],
#   'Molecules': ['N1', 'Li2', 'Li3', 'Li4'],
#   'Name': 'Li3N',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['-0.3033', '1.7218', '0.0000'],
#    ['1.6428', '-0.5982', '0.0000'],
#    ['-1.3394', '-1.1236', '0.0000']]},
#  'LiCl': {'Internal': [['0.0000', '0.0000', '-1.7461'],
#    ['0.0000', '0.0000', '0.3081']],
#   'Molecules': ['Li1', 'Cl2'],
#   'Name': 'LiCl'},
#  'LiF': {'Internal': [['0.0000', '0.0000', '0.3878'],
#    ['0.0000', '0.0000', '-1.1635']],
#   'Molecules': ['F1', 'Li2'],
#   'Name': 'LiF'},
#  'LiH': {'Internal': [['0.0000', '0.0000', '0.4054'],
#    ['0.0000', '0.0000', '-1.2161']],
#   'Molecules': ['Li1', 'H2'],
#   'Name': 'LiH'},
#  'LiOH': {'Internal': [['0.0000', '0.0000', '0.3163'],
#    ['0.0000', '0.0000', '-1.2685'],
#    ['0.0000', '0.0000', '1.2748']],
#   'Molecules': ['O1', 'Li2', 'H3'],
#   'Name': 'LiOH',
#   'Principal': [['0.3163', '0.0000', '0.0000'],
#    ['-1.2685', '0.0000', '0.0000'],
#    ['1.2748', '0.0000', '0.0000']]},
#  'MgCl2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '2.1933'],
#    ['0.0000', '0.0000', '-2.1933']],
#   'Molecules': ['Mg1', 'Cl2', 'Cl3'],
#   'Name': 'MgCl2',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['2.1933', '0.0000', '0.0000'],
#    ['-2.1933', '0.0000', '0.0000']]},
#  'MgF2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.7371'],
#    ['0.0000', '0.0000', '-1.7371']],
#   'Molecules': ['Mg1', 'F2', 'F3'],
#   'Name': 'MgF2'},
#  'MgH2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.7121'],
#    ['0.0000', '0.0000', '-1.7121']],
#   'Molecules': ['Mg1', 'H2', 'H3'],
#   'Name': 'MgH2'},
#  'MgO': {'Internal': [['0.0000', '0.0000', '0.6976'],
#    ['0.0000', '0.0000', '-1.0464']],
#   'Molecules': ['Mg1', 'O2'],
#   'Name': 'MgO',
#   'Principal': [['0.6976', '0.0000', '0.0000'],
#    ['-1.0464', '0.0000', '0.0000']]},
#  'MgS': {'Internal': [['0.0000', '0.0000', '-1.2356'],
#    ['0.0000', '0.0000', '0.9267']],
#   'Molecules': ['Mg1', 'S2'],
#   'Name': 'MgS',
#   'Principal': [['-1.2356', '0.0000', '0.0000'],
#    ['0.9267', '0.0000', '0.0000']]},
#  'NH3': {'Internal': [['0.0000', '0.0000', '0.1193'],
#    ['0.0000', '0.9386', '-0.2785'],
#    ['0.8129', '-0.4693', '-0.2785'],
#    ['-0.8129', '-0.4693', '-0.2785']],
#   'Molecules': ['N1', 'H2', 'H3', 'H4'],
#   'Name': 'NH3',
#   'Principal': [['0.0000', '0.0000', '0.1193'],
#    ['0.8395', '0.4198', '-0.2785'],
#    ['-0.7833', '0.5172', '-0.2785'],
#    ['-0.0562', '-0.9369', '-0.2785']]},
#  'NO': {'Internal': [['0.0000', '0.0000', '0.5407'],
#    ['0.0000', '0.0000', '-0.6180']],
#   'Molecules': ['O1', 'N2'],
#   'Name': 'NO'},
#  'NO2': {'Internal': [['0.0000', '0.0000', '0.3281'],
#    ['0.0000', '1.1068', '-0.1436'],
#    ['0.0000', '-1.1068', '-0.1436']],
#   'Molecules': ['N1', 'O2', 'O3'],
#   'Name': 'NO2',
#   'Principal': [['0.0000', '0.3281', '0.0000'],
#    ['1.1068', '-0.1436', '0.0000'],
#    ['-1.1068', '-0.1436', '0.0000']]},
#  'Na2O': {'Internal': [['0.0000', '0.0000', '0.2473'],
#    ['0.0000', '1.9403', '-0.0899'],
#    ['0.0000', '-1.9403', '-0.0899']],
#   'Molecules': ['O1', 'Na2', 'Na3'],
#   'Name': 'Na2O',
#   'Principal': [['0.0000', '0.2473', '0.0000'],
#    ['1.9403', '-0.0899', '0.0000'],
#    ['-1.9403', '-0.0899', '0.0000']]},
#  'NaCl': {'Internal': [['0.0000', '0.0000', '-1.4426'],
#    ['0.0000', '0.0000', '0.9334']],
#   'Molecules': ['Na1', 'Cl2'],
#   'Name': 'NaCl'},
#  'NaF': {'Internal': [['0.0000', '0.0000', '0.8512'],
#    ['0.0000', '0.0000', '-1.0404']],
#   'Molecules': ['Na1', 'F2'],
#   'Name': 'NaF'},
#  'NaH': {'Internal': [['0.0000', '0.0000', '0.1570'],
#    ['0.0000', '0.0000', '-1.7273']],
#   'Molecules': ['Na1', 'H2'],
#   'Name': 'NaH'},
#  'Ne': {'Internal': [['0.0000', '0.0000', '0.0000']],
#   'Molecules': ['Ne1'],
#   'Name': 'Ne'},
#  'O2': {'Internal': [['0.0000', '0.0000', '0.6073'],
#    ['0.0000', '0.0000', '-0.6073']],
#   'Molecules': ['O1', 'O2'],
#   'Name': 'O2'},
#  'OF2': {'Internal': [['0.0000', '0.0000', '0.6012'],
#    ['0.0000', '1.1095', '-0.2672'],
#    ['0.0000', '-1.1095', '-0.2672']],
#   'Molecules': ['O1', 'F2', 'F3'],
#   'Name': 'OF2',
#   'Principal': [['0.0000', '0.6012', '0.0000'],
#    ['1.1095', '-0.2672', '0.0000'],
#    ['-1.1095', '-0.2672', '0.0000']]},
#  'PH3': {'Internal': [['0.0000', '0.0000', '0.1288'],
#    ['0.0000', '1.1965', '-0.6439'],
#    ['1.0362', '-0.5983', '-0.6439'],
#    ['-1.0362', '-0.5983', '-0.6439']],
#   'Molecules': ['P1', 'H2', 'H3', 'H4'],
#   'Name': 'PH3'},
#  'SO2': {'Internal': [['0.0000', '0.0000', '0.3706'],
#    ['0.0000', '1.2622', '-0.3706'],
#    ['0.0000', '-1.2622', '-0.3706']],
#   'Molecules': ['S1', 'O2', 'O3'],
#   'Name': 'SO2',
#   'Principal': [['0.0000', '0.3706', '0.0000'],
#    ['1.2622', '-0.3706', '0.0000'],
#    ['-1.2622', '-0.3706', '0.0000']]},
#  'SiC': {'Internal': [['0.0000', '0.0000', '0.5171'],
#    ['0.0000', '0.0000', '-1.2065']],
#   'Molecules': ['Si1', 'C2'],
#   'Name': 'SiC'},
#  'SiCl4': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['1.1821', '1.1821', '1.1821'],
#    ['-1.1821', '-1.1821', '1.1821'],
#    ['-1.1821', '1.1821', '-1.1821'],
#    ['1.1821', '-1.1821', '-1.1821']],
#   'Molecules': ['Si1', 'Cl2', 'Cl3', 'Cl4', 'Cl5'],
#   'Name': 'SiCl4',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['0.4908', '1.1821', '1.5981'],
#    ['-0.4908', '1.1821', '-1.5981'],
#    ['-1.5981', '-1.1821', '0.4908'],
#    ['1.5981', '-1.1821', '-0.4908']]},
#  'SiF4': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.9117', '0.9117', '0.9117'],
#    ['-0.9117', '-0.9117', '0.9117'],
#    ['-0.9117', '0.9117', '-0.9117'],
#    ['0.9117', '-0.9117', '-0.9117']],
#   'Molecules': ['Si1', 'F2', 'F3', 'F4', 'F5'],
#   'Name': 'SiF4',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['0.9117', '0.2998', '1.2540'],
#    ['0.9117', '-0.2998', '-1.2540'],
#    ['-0.9117', '-1.2540', '0.2998'],
#    ['-0.9117', '1.2540', '-0.2998']]},
#  'SiH4': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.8579', '0.8579', '0.8579'],
#    ['-0.8579', '-0.8579', '0.8579'],
#    ['-0.8579', '0.8579', '-0.8579'],
#    ['0.8579', '-0.8579', '-0.8579']],
#   'Molecules': ['Si1', 'H2', 'H3', 'H4', 'H5'],
#   'Name': 'SiH4',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['0.9843', '0.8579', '0.7094'],
#    ['-0.9843', '0.8579', '-0.7094'],
#    ['-0.7094', '-0.8579', '0.9843'],
#    ['0.7094', '-0.8579', '-0.9843']]},
#  'SiO2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.5197'],
#    ['0.0000', '0.0000', '-1.5197']],
#   'Molecules': ['Si1', 'O2', 'O3'],
#   'Name': 'SiO2',
#   'Principal': [['0.0000', '0.0000', '0.0000'],
#    ['1.5197', '0.0000', '0.0000'],
#    ['-1.5197', '0.0000', '0.0000']]},
#  'SiS2': {'Internal': [['0.0000', '0.0000', '0.0000'],
#    ['0.0000', '0.0000', '1.9391'],
#    ['0.0000', '0.0000', '-1.9391']],
#   'Molecules': ['Si1', 'S2', 'S3'],
#   'Name': 'SiS2'}}

# %%
mole = 'H2'   # set the molucular
geometry = list(zip(map(lambda x:x[:-1], Molecules_Data['H2']['Molecules']), [tuple(map(float, x)) for x in Molecules_Data['H2']['Internal']]))
active_space_start = 0 
active_space_stop = 2

# %%
#set the parameters for pyscf
basis = 'sto-6g'# gaussian wavefuctions
multiplicity = 1  # multiplet
charge = 0 # molecular charge
description = 'ccsd' # mark for saving file

# set the calculator, 0-shut down, 1-turn on
run_scf = 1 
run_mp2 = 1
run_ccsd = 1
run_cisd = 0
run_fci = 1
delete_input = True
delete_output = True

# %% [markdown]
# # 2. Compute the hamiltonian of the system

# %%
# calculation from parameters
molecule = MolecularData(geometry, basis, multiplicity, charge, description)
molecule = run_pyscf(molecule, run_scf=run_scf,run_mp2=run_mp2, run_cisd=run_cisd, run_ccsd=run_ccsd, run_fci=run_fci)
print('Hartree-Fock energy of {} Hartree.'.format(molecule.hf_energy))
print('MP2 energy of {} Hartree.'.format(molecule.mp2_energy))
print('FCI energy of {} Hartree.'.format(molecule.fci_energy))
print('Nuclear repulsion energy between protons is {} Hartree.'.format(
    molecule.nuclear_repulsion))
for orbital in range(molecule.n_orbitals):
    print('Spatial orbital {} has energy of {} Hartree.'.format(
        orbital, molecule.orbital_energies[orbital]))
MolecularData.save(molecule)
molecule.load()
# Out:
# Hartree-Fock energy of -1.1252095979375198 Hartree.
# MP2 energy of -1.1384431580364507 Hartree.
# FCI energy of -1.145900469958307 Hartree.
# Nuclear repulsion energy between protons is 0.7124087384491115 Hartree.
# Spatial orbital 0 has energy of -0.5817274220336034 Hartree.
# Spatial orbital 1 has energy of 0.6650468891904611 Hartree.

# %%
# get the hamiltonian for the molecular
molecule_hamiltonian = molecule.get_molecular_hamiltonian(occupied_indices=range(
    active_space_start), active_indices=range(active_space_start, active_space_stop))
# change the hamiltonian to fermion operator
fermion_hamiltonian = get_fermion_operator(molecule_hamiltonian)

# J-W transformation for modified fermion operator
qubit_hamiltonian_JW = jordan_wigner(fermion_hamiltonian)
qubit_hamiltonian_JW.compress()
print('The Jordan-Wigner Hamiltonian in canonical basis follows:\n{}', format(qubit_hamiltonian_JW))

# B-K transformation for modified fermion operator
qubit_hamiltonian_BK = bravyi_kitaev(fermion_hamiltonian)
print('qubit_hamiltonian BK transfer fermion_hamiltonian', format(qubit_hamiltonian_BK))
# Out:
# The Jordan-Wigner Hamiltonian in canonical basis follows:
# {} -0.10828642633408778 [] +
# -0.045413740730899495 [X0 X1 Y2 Y3] +
# 0.045413740730899495 [X0 Y1 Y2 X3] +
# 0.045413740730899495 [Y0 X1 X2 Y3] +
# -0.045413740730899495 [Y0 Y1 X2 X3] +
# 0.17287043695155 [Z0] +
# 0.1685408730798563 [Z0 Z1] +
# 0.12056020320710414 [Z0 Z2] +
# 0.16597394393800363 [Z0 Z3] +
# 0.1728704369515501 [Z1] +
# 0.16597394393800363 [Z1 Z2] +
# 0.12056020320710414 [Z1 Z3] +
# -0.2206655790398497 [Z2] +
# 0.17467628158972687 [Z2 Z3] +
# -0.2206655790398497 [Z3]
# qubit_hamiltonian BK transfer fermion_hamiltonian (-0.10828642633408778+0j) [] +
# (0.045413740730899495+0j) [X0 Z1 X2] +
# (0.045413740730899495+0j) [X0 Z1 X2 Z3] +
# (0.045413740730899495+0j) [Y0 Z1 Y2] +
# (0.045413740730899495+0j) [Y0 Z1 Y2 Z3] +
# (0.17287043695155+0j) [Z0] +
# (0.1728704369515501+0j) [Z0 Z1] +
# (0.16597394393800363+0j) [Z0 Z1 Z2] +
# (0.16597394393800363+0j) [Z0 Z1 Z2 Z3] +
# (0.12056020320710414+0j) [Z0 Z2] +
# (0.12056020320710414+0j) [Z0 Z2 Z3] +
# (0.1685408730798563+0j) [Z1] +
# (-0.2206655790398497+0j) [Z1 Z2 Z3] +
# (0.17467628158972687+0j) [Z1 Z3] +
# (-0.2206655790398497+0j) [Z2]

# %% [markdown]
# ## In this part we compute the ground state of the molecula in normal way.
# ## It is used for the comparation with FQE method.

# %%
# change the qubit_hamiltonian_JW to sparse_operator 
sparse_operator = get_sparse_operator(qubit_hamiltonian_JW)
H_csr = sparse_operator.tocsr()

# calculater the eigenvalue and eigen state of sparse_operator
V, D = sp.sparse.linalg.eigs(sparse_operator)

# compute the energy of the ground state
E_theory = np.min(V)
print('E_theory',E_theory)
Ha = sparse_operator.todense()
Ha = np.mat(Ha)
# Out:
# E_theory (-1.1459004699583069+1.9643867502022242e-17j)

# %%
# get the initial ansaz state
H0 = np.diagonal(Ha)
jj = np.argmin(H0)
initial_state = np.zeros(len(Ha))
initial_state[jj] = 1       # initial ansaz state

# %% [markdown]
# # 3. Simulation with FullQuantumEigensolver(FQE)

# %%
from projectq import MainEngine
from projectq.ops import All, CNOT, H, Measure, X, Z, C, Y, CX, QubitOperator, StatePreparation, FlipBits
from projectq.backends import CircuitDrawer
import math
import numpy as np

# %%
class FullQuantumEigensolver:
    def __init__(self, Gatelist, active_space_stop, active_space_start, working_state, gamma=1):
        self.gamma = gamma                                                   # parameter gamma
        self.ancilla_num = math.ceil(math.log(len(Gatelist)) / math.log(2))  # number of  ancilla qubits
        self.working_num = (active_space_stop - active_space_start) * 2      # number of working qubits
        self.gates_list = list(map(lambda x:x[0], Gatelist))                 # the gates set for fqe (pauli product items of hamiltonian)
        self.ancilla_state = self.cal_coe_list(Gatelist)                     # the initial state of ancilla qubits
        self.working_state = working_state                                   # the inital state of working qubits
        self.flip_position = []                                              # the flip postion for graycode                                          
        for i in range(self.ancilla_num):
            self.flip_position = self.flip_position + [i] + self.flip_position

    # run FQE, iteration times - n
    def start(self, n):
        for i in range(n):
            self.working_state = self.reverseMap(self.working_state)
            eng = MainEngine()
            final_state = self.quantumIter(eng)
            final_state = np.array(list(map(lambda x:x[1], final_state.items())))
            possibility = sum(abs(final_state)**2)
            final_state = final_state / math.sqrt(possibility)
            Energy = self.cal_E(final_state, H_csr)
            self.log(i+1, final_state, possibility, Energy)
            self.working_state = final_state
    
    # calculate the initial state of ancilla qubits
    def cal_coe_list(self, Gatelist):
        coe_list = [0] + list(map(lambda x:x[1], Gatelist))
        coe_list.extend([0 for x in range((1 << self.ancilla_num) - len(coe_list))])
        coe_list = np.array(coe_list)
        coe_list = -self.gamma * coe_list
        coe_list[0] = 1
        coe_list = coe_list / math.sqrt(sum(coe_list * coe_list))
        gray_code = [0]
        for i in range(self.ancilla_num):
            gray_code += [(1 << i) + gray_code[-j-1] for j in range(1 << i)]
        coe_list_m = np.zeros(len(coe_list))
        for i in range(len(coe_list)):
            coe_list_m[gray_code[i]] = coe_list[i]
    
        return coe_list_m
    
    # with hamiltonian-H_csr, compute the energy
    def cal_E(self, state, H_csr):
        state = np.matrix(state)
        state = sp.sparse.csr_matrix(state)
        E = np.real((state.conjugate().tocsr() * H_csr * state.transpose()).toarray()[0][0])
        return E
    
    # iteration
    def quantumIter(self, eng):
        eng, qreg = self.circuit_build(eng)
        try:
            eng.flush()
        except:
            pass
        anc_state = '0' * self.ancilla_num

        return self.post_select(eng, qreg, anc_state)
    
    # reverse the quantum state, because the  projectq
    def reverseMap(self, state):
        length = len(state)
        rmap = np.zeros(length, dtype=np.int32)
        for i in range(length):
            rmap[i] = int("{:0>{}b}".format(i, self.working_num)[::-1], 2)
        state_new = np.zeros(len(state))
        for i, coe in enumerate(state):
            state_new[rmap[i]] = coe
            
        return state_new
        
    # bulid the quantum circuit
    def circuit_build(self, eng):
        # allocate qubit register
        ancillas = eng.allocate_qureg(self.ancilla_num)
        working_qubits = eng.allocate_qureg(self.working_num)
        
        # initial state
        StatePreparation(self.ancilla_state) | ancillas
        StatePreparation(self.working_state) | working_qubits
        FlipBits(-1) | ancillas
        
        # quantum gate
        for i, gates in enumerate(self.gates_list):
            X | ancillas[self.flip_position[i]]
            for gate in gates:
                C(eval(gate[1]), self.ancilla_num) | (ancillas, working_qubits[gate[0]])
        i += 1
        while i < len(self.flip_position):

            X | ancillas[self.flip_position[i]]
            i += 1
        
        X | ancillas[self.ancilla_num-1]
        FlipBits(-1) | ancillas

        for i in range(self.ancilla_num):
            H | ancillas[i]
            
        return eng, ancillas+working_qubits
    
    # post select the quantum state
    def post_select(self, eng, qreg, anc_state):
        dct = {}
        for i in range(len(self.working_state)):
            num2 = bin(i)[2:]
            num2 = '0' * (self.working_num - len(num2)) + num2
            dct[num2] = eng.backend.get_amplitude(anc_state+num2, qreg)
        return dct
    
    # log 
    def log(self, i, final_state, possibility, energy):
        print('The {}\'s iteration'.format(i))
        print("Energy: {}".format(energy))
        print('The final remain state after select:')
        print(final_state)
        print('select possibility: {}'.format(possibility))
        
    # print latex code for the circuit
    def plot_circuits(self):
        drawing_engine = CircuitDrawer()
        eng = MainEngine(drawing_engine)
        eng = self.circuit_build(eng)[0]
        eng.flush()
        print(drawing_engine.get_latex())

# %%
# get the gatelist (pauli product items of the hamiltonian after JW tranformation
Gatelist = list(qubit_hamiltonian_JW.terms.items())

# %%
# get the FullQuantumEigensolver
FQE = FullQuantumEigensolver(Gatelist, active_space_stop, active_space_start, initial_state)

# %%
# estimate the iteration times - K
epsilon = 1e-4
gamma = 1
H1 = sorted(H0)
K = math.log(epsilon / len(H0)) / math.log((1 - gamma * H1[1]) / (1 - gamma * H1[0]))
K = math.ceil(K)

# %%
# run FQE (K iterations)
FQE.start(K)

# %%
# print the latex code for circuit
FQE.plot_circuits()
# Out:
# \documentclass{standalone}
# \usepackage[margin=1in]{geometry}
# \usepackage[hang,small,bf]{caption}
# \usepackage{tikz}
# \usepackage{braket}
# \usetikzlibrary{backgrounds,shadows.blur,fit,decorations.pathreplacing,shapes}
#
# \begin{document}
# \begin{tikzpicture}[scale=0.8, transform shape]
#
# \tikzstyle{basicshadow}=[blur shadow={shadow blur steps=8, shadow xshift=0.7pt, shadow yshift=-0.7pt, shadow scale=1.02}]\tikzstyle{basic}=[draw,fill=white,basicshadow]
# \tikzstyle{operator}=[basic,minimum size=1.5em]
# \tikzstyle{phase}=[fill=black,shape=circle,minimum size=0.1cm,inner sep=0pt,outer sep=0pt,draw=black]
# \tikzstyle{none}=[inner sep=0pt,outer sep=-.5pt,minimum height=0.5cm+1pt]
# \tikzstyle{measure}=[operator,inner sep=0pt,minimum height=0.5cm, minimum width=0.75cm]
# \tikzstyle{xstyle}=[circle,basic,minimum height=0.35cm,minimum width=0.35cm,inner sep=-1pt,very thin]
# \tikzset{
# shadowed/.style={preaction={transform canvas={shift={(0.5pt,-0.5pt)}}, draw=gray, opacity=0.4}},
# }
# \tikzstyle{swapstyle}=[inner sep=-1pt, outer sep=-1pt, minimum width=0pt]
# \tikzstyle{edgestyle}=[very thin]
#
# \node[none] (line0_gate0) at (0.1,-0) {$\Ket{0}$};
# \node[none] (line1_gate0) at (0.1,-1) {$\Ket{0}$};
# \node[none] (line2_gate0) at (0.1,-2) {$\Ket{0}$};
# \node[none] (line3_gate0) at (0.1,-3) {$\Ket{0}$};
# \node[none] (line0_gate1) at (0.6000000000000001,-0) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line0_gate2) at (0.8500000000000001,-0) {};
# \node[none] (line0_gate3) at (1.1,-0) {};
# \node[none] (line1_gate1) at (0.6000000000000001,-1) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line1_gate2) at (0.8500000000000001,-1) {};
# \node[none] (line1_gate3) at (1.1,-1) {};
# \node[none] (line2_gate1) at (0.6000000000000001,-2) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line2_gate2) at (0.8500000000000001,-2) {};
# \node[none] (line2_gate3) at (1.1,-2) {};
# \node[none] (line3_gate1) at (0.6000000000000001,-3) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line3_gate2) at (0.8500000000000001,-3) {};
# \node[none] (line3_gate3) at (1.1,-3) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line0_gate1) rectangle ([yshift=-0.25cm]line3_gate3) node[pos=.5] {StatePreparation};
# \draw (line0_gate0) edge[edgestyle] (line0_gate1);
# \draw (line1_gate0) edge[edgestyle] (line1_gate1);
# \draw (line2_gate0) edge[edgestyle] (line2_gate1);
# \draw (line3_gate0) edge[edgestyle] (line3_gate1);
# \node[none] (line4_gate0) at (0.1,-4) {$\Ket{0}$};
# \node[none] (line5_gate0) at (0.1,-5) {$\Ket{0}$};
# \node[none] (line6_gate0) at (0.1,-6) {$\Ket{0}$};
# \node[none] (line7_gate0) at (0.1,-7) {$\Ket{0}$};
# \node[none] (line4_gate1) at (0.6000000000000001,-4) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line4_gate2) at (0.8500000000000001,-4) {};
# \node[none] (line4_gate3) at (1.1,-4) {};
# \node[none] (line5_gate1) at (0.6000000000000001,-5) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line5_gate2) at (0.8500000000000001,-5) {};
# \node[none] (line5_gate3) at (1.1,-5) {};
# \node[none] (line6_gate1) at (0.6000000000000001,-6) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line6_gate2) at (0.8500000000000001,-6) {};
# \node[none] (line6_gate3) at (1.1,-6) {};
# \node[none] (line7_gate1) at (0.6000000000000001,-7) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line7_gate2) at (0.8500000000000001,-7) {};
# \node[none] (line7_gate3) at (1.1,-7) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line4_gate1) rectangle ([yshift=-0.25cm]line7_gate3) node[pos=.5] {StatePreparation};
# \draw (line4_gate0) edge[edgestyle] (line4_gate1);
# \draw (line5_gate0) edge[edgestyle] (line5_gate1);
# \draw (line6_gate0) edge[edgestyle] (line6_gate1);
# \draw (line7_gate0) edge[edgestyle] (line7_gate1);
# \node[xstyle] (line2_gate4) at (1.4000000000000001,-2) {};
# \draw[edgestyle] (line2_gate4.north)--(line2_gate4.south);
# \draw[edgestyle] (line2_gate4.west)--(line2_gate4.east);
# \draw (line2_gate3) edge[edgestyle] (line2_gate4);
# \node[xstyle] (line3_gate4) at (1.4000000000000001,-3) {};
# \draw[edgestyle] (line3_gate4.north)--(line3_gate4.south);
# \draw[edgestyle] (line3_gate4.west)--(line3_gate4.east);
# \draw (line3_gate3) edge[edgestyle] (line3_gate4);
# \node[phase] (line4_gate4) at (2.0500000000000003,-4) {};
# \node[phase] (line0_gate4) at (2.0500000000000003,-0) {};
# \draw (line0_gate4) edge[edgestyle] (line4_gate4);
# \node[phase] (line1_gate4) at (2.0500000000000003,-1) {};
# \draw (line1_gate4) edge[edgestyle] (line4_gate4);
# \node[phase] (line2_gate5) at (2.0500000000000003,-2) {};
# \draw (line2_gate5) edge[edgestyle] (line4_gate4);
# \node[phase] (line3_gate5) at (2.0500000000000003,-3) {};
# \draw (line3_gate5) edge[edgestyle] (line4_gate4);
# \draw (line4_gate3) edge[edgestyle] (line4_gate4);
# \draw (line0_gate3) edge[edgestyle] (line0_gate4);
# \draw (line1_gate3) edge[edgestyle] (line1_gate4);
# \draw (line2_gate4) edge[edgestyle] (line2_gate5);
# \draw (line3_gate4) edge[edgestyle] (line3_gate5);
# \node[xstyle] (line0_gate5) at (2.8500000000000005,-0) {};
# \draw[edgestyle] (line0_gate5.north)--(line0_gate5.south);
# \draw[edgestyle] (line0_gate5.west)--(line0_gate5.east);
# \draw (line0_gate4) edge[edgestyle] (line0_gate5);
# \node[phase] (line5_gate4) at (3.500000000000001,-5) {};
# \node[phase] (line0_gate6) at (3.500000000000001,-0) {};
# \draw (line0_gate6) edge[edgestyle] (line5_gate4);
# \node[phase] (line1_gate5) at (3.500000000000001,-1) {};
# \draw (line1_gate5) edge[edgestyle] (line5_gate4);
# \node[phase] (line2_gate6) at (3.500000000000001,-2) {};
# \draw (line2_gate6) edge[edgestyle] (line5_gate4);
# \node[phase] (line3_gate6) at (3.500000000000001,-3) {};
# \draw (line3_gate6) edge[edgestyle] (line5_gate4);
# \draw (line5_gate3) edge[edgestyle] (line5_gate4);
# \draw (line0_gate5) edge[edgestyle] (line0_gate6);
# \draw (line1_gate4) edge[edgestyle] (line1_gate5);
# \draw (line2_gate5) edge[edgestyle] (line2_gate6);
# \draw (line3_gate5) edge[edgestyle] (line3_gate6);
# \node[xstyle] (line2_gate7) at (4.300000000000001,-2) {};
# \draw[edgestyle] (line2_gate7.north)--(line2_gate7.south);
# \draw[edgestyle] (line2_gate7.west)--(line2_gate7.east);
# \draw (line2_gate6) edge[edgestyle] (line2_gate7);
# \node[phase] (line6_gate4) at (4.95,-6) {};
# \node[phase] (line0_gate7) at (4.95,-0) {};
# \draw (line0_gate7) edge[edgestyle] (line6_gate4);
# \node[phase] (line1_gate6) at (4.95,-1) {};
# \draw (line1_gate6) edge[edgestyle] (line6_gate4);
# \node[phase] (line2_gate8) at (4.95,-2) {};
# \draw (line2_gate8) edge[edgestyle] (line6_gate4);
# \node[phase] (line3_gate7) at (4.95,-3) {};
# \draw (line3_gate7) edge[edgestyle] (line6_gate4);
# \draw (line6_gate3) edge[edgestyle] (line6_gate4);
# \draw (line0_gate6) edge[edgestyle] (line0_gate7);
# \draw (line1_gate5) edge[edgestyle] (line1_gate6);
# \draw (line2_gate7) edge[edgestyle] (line2_gate8);
# \draw (line3_gate6) edge[edgestyle] (line3_gate7);
# \node[xstyle] (line0_gate8) at (5.75,-0) {};
# \draw[edgestyle] (line0_gate8.north)--(line0_gate8.south);
# \draw[edgestyle] (line0_gate8.west)--(line0_gate8.east);
# \draw (line0_gate7) edge[edgestyle] (line0_gate8);
# \node[phase] (line7_gate4) at (6.3999999999999995,-7) {};
# \node[phase] (line0_gate9) at (6.3999999999999995,-0) {};
# \draw (line0_gate9) edge[edgestyle] (line7_gate4);
# \node[phase] (line1_gate7) at (6.3999999999999995,-1) {};
# \draw (line1_gate7) edge[edgestyle] (line7_gate4);
# \node[phase] (line2_gate9) at (6.3999999999999995,-2) {};
# \draw (line2_gate9) edge[edgestyle] (line7_gate4);
# \node[phase] (line3_gate8) at (6.3999999999999995,-3) {};
# \draw (line3_gate8) edge[edgestyle] (line7_gate4);
# \draw (line7_gate3) edge[edgestyle] (line7_gate4);
# \draw (line0_gate8) edge[edgestyle] (line0_gate9);
# \draw (line1_gate6) edge[edgestyle] (line1_gate7);
# \draw (line2_gate8) edge[edgestyle] (line2_gate9);
# \draw (line3_gate7) edge[edgestyle] (line3_gate8);
# \node[xstyle] (line1_gate8) at (7.199999999999999,-1) {};
# \draw[edgestyle] (line1_gate8.north)--(line1_gate8.south);
# \draw[edgestyle] (line1_gate8.west)--(line1_gate8.east);
# \draw (line1_gate7) edge[edgestyle] (line1_gate8);
# \node[phase] (line4_gate5) at (7.849999999999999,-4) {};
# \node[phase] (line0_gate10) at (7.849999999999999,-0) {};
# \draw (line0_gate10) edge[edgestyle] (line4_gate5);
# \node[phase] (line1_gate9) at (7.849999999999999,-1) {};
# \draw (line1_gate9) edge[edgestyle] (line4_gate5);
# \node[phase] (line2_gate10) at (7.849999999999999,-2) {};
# \draw (line2_gate10) edge[edgestyle] (line4_gate5);
# \node[phase] (line3_gate9) at (7.849999999999999,-3) {};
# \draw (line3_gate9) edge[edgestyle] (line4_gate5);
# \draw (line4_gate4) edge[edgestyle] (line4_gate5);
# \draw (line0_gate9) edge[edgestyle] (line0_gate10);
# \draw (line1_gate8) edge[edgestyle] (line1_gate9);
# \draw (line2_gate9) edge[edgestyle] (line2_gate10);
# \draw (line3_gate8) edge[edgestyle] (line3_gate9);
# \node[phase] (line5_gate5) at (8.749999999999998,-5) {};
# \node[phase] (line0_gate11) at (8.749999999999998,-0) {};
# \draw (line0_gate11) edge[edgestyle] (line5_gate5);
# \node[phase] (line1_gate10) at (8.749999999999998,-1) {};
# \draw (line1_gate10) edge[edgestyle] (line5_gate5);
# \node[phase] (line2_gate11) at (8.749999999999998,-2) {};
# \draw (line2_gate11) edge[edgestyle] (line5_gate5);
# \node[phase] (line3_gate10) at (8.749999999999998,-3) {};
# \draw (line3_gate10) edge[edgestyle] (line5_gate5);
# \draw (line5_gate4) edge[edgestyle] (line5_gate5);
# \draw (line0_gate10) edge[edgestyle] (line0_gate11);
# \draw (line1_gate9) edge[edgestyle] (line1_gate10);
# \draw (line2_gate10) edge[edgestyle] (line2_gate11);
# \draw (line3_gate9) edge[edgestyle] (line3_gate10);
# \node[xstyle] (line0_gate12) at (9.549999999999997,-0) {};
# \draw[edgestyle] (line0_gate12.north)--(line0_gate12.south);
# \draw[edgestyle] (line0_gate12.west)--(line0_gate12.east);
# \draw (line0_gate11) edge[edgestyle] (line0_gate12);
# \node[none] (line4_gate6) at (10.199999999999996,-4) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line4_gate7) at (10.449999999999996,-4) {};
# \node[none] (line4_gate8) at (10.699999999999996,-4) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line4_gate6) rectangle ([yshift=-0.25cm]line4_gate8) node[pos=.5] {Y};
# \node[phase] (line0_gate13) at (10.449999999999996,-0) {};
# \draw (line0_gate13) edge[edgestyle] (line4_gate7);
# \node[phase] (line1_gate11) at (10.449999999999996,-1) {};
# \draw (line1_gate11) edge[edgestyle] (line4_gate7);
# \node[phase] (line2_gate12) at (10.449999999999996,-2) {};
# \draw (line2_gate12) edge[edgestyle] (line4_gate7);
# \node[phase] (line3_gate11) at (10.449999999999996,-3) {};
# \draw (line3_gate11) edge[edgestyle] (line4_gate7);
# \draw (line4_gate5) edge[edgestyle] (line4_gate6);
# \draw (line0_gate12) edge[edgestyle] (line0_gate13);
# \draw (line1_gate10) edge[edgestyle] (line1_gate11);
# \draw (line2_gate11) edge[edgestyle] (line2_gate12);
# \draw (line3_gate10) edge[edgestyle] (line3_gate11);
# \node[xstyle] (line5_gate6) at (10.999999999999995,-5) {};
# \draw[edgestyle] (line5_gate6.north)--(line5_gate6.south);
# \draw[edgestyle] (line5_gate6.west)--(line5_gate6.east);
# \node[phase] (line0_gate14) at (10.999999999999995,-0) {};
# \draw (line0_gate14) edge[edgestyle] (line5_gate6);
# \node[phase] (line1_gate12) at (10.999999999999995,-1) {};
# \draw (line1_gate12) edge[edgestyle] (line5_gate6);
# \node[phase] (line2_gate13) at (10.999999999999995,-2) {};
# \draw (line2_gate13) edge[edgestyle] (line5_gate6);
# \node[phase] (line3_gate12) at (10.999999999999995,-3) {};
# \draw (line3_gate12) edge[edgestyle] (line5_gate6);
# \draw (line5_gate5) edge[edgestyle] (line5_gate6);
# \draw (line0_gate13) edge[edgestyle] (line0_gate14);
# \draw (line1_gate11) edge[edgestyle] (line1_gate12);
# \draw (line2_gate12) edge[edgestyle] (line2_gate13);
# \draw (line3_gate11) edge[edgestyle] (line3_gate12);
# \node[xstyle] (line6_gate5) at (11.549999999999994,-6) {};
# \draw[edgestyle] (line6_gate5.north)--(line6_gate5.south);
# \draw[edgestyle] (line6_gate5.west)--(line6_gate5.east);
# \node[phase] (line0_gate15) at (11.549999999999994,-0) {};
# \draw (line0_gate15) edge[edgestyle] (line6_gate5);
# \node[phase] (line1_gate13) at (11.549999999999994,-1) {};
# \draw (line1_gate13) edge[edgestyle] (line6_gate5);
# \node[phase] (line2_gate14) at (11.549999999999994,-2) {};
# \draw (line2_gate14) edge[edgestyle] (line6_gate5);
# \node[phase] (line3_gate13) at (11.549999999999994,-3) {};
# \draw (line3_gate13) edge[edgestyle] (line6_gate5);
# \draw (line6_gate4) edge[edgestyle] (line6_gate5);
# \draw (line0_gate14) edge[edgestyle] (line0_gate15);
# \draw (line1_gate12) edge[edgestyle] (line1_gate13);
# \draw (line2_gate13) edge[edgestyle] (line2_gate14);
# \draw (line3_gate12) edge[edgestyle] (line3_gate13);
# \node[none] (line7_gate5) at (12.199999999999992,-7) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line7_gate6) at (12.449999999999992,-7) {};
# \node[none] (line7_gate7) at (12.699999999999992,-7) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line7_gate5) rectangle ([yshift=-0.25cm]line7_gate7) node[pos=.5] {Y};
# \node[phase] (line0_gate16) at (12.449999999999992,-0) {};
# \draw (line0_gate16) edge[edgestyle] (line7_gate6);
# \node[phase] (line1_gate14) at (12.449999999999992,-1) {};
# \draw (line1_gate14) edge[edgestyle] (line7_gate6);
# \node[phase] (line2_gate15) at (12.449999999999992,-2) {};
# \draw (line2_gate15) edge[edgestyle] (line7_gate6);
# \node[phase] (line3_gate14) at (12.449999999999992,-3) {};
# \draw (line3_gate14) edge[edgestyle] (line7_gate6);
# \draw (line7_gate4) edge[edgestyle] (line7_gate5);
# \draw (line0_gate15) edge[edgestyle] (line0_gate16);
# \draw (line1_gate13) edge[edgestyle] (line1_gate14);
# \draw (line2_gate14) edge[edgestyle] (line2_gate15);
# \draw (line3_gate13) edge[edgestyle] (line3_gate14);
# \node[xstyle] (line3_gate15) at (12.999999999999991,-3) {};
# \draw[edgestyle] (line3_gate15.north)--(line3_gate15.south);
# \draw[edgestyle] (line3_gate15.west)--(line3_gate15.east);
# \draw (line3_gate14) edge[edgestyle] (line3_gate15);
# \node[none] (line4_gate9) at (13.64999999999999,-4) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line4_gate10) at (13.89999999999999,-4) {};
# \node[none] (line4_gate11) at (14.14999999999999,-4) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line4_gate9) rectangle ([yshift=-0.25cm]line4_gate11) node[pos=.5] {Y};
# \node[phase] (line0_gate17) at (13.89999999999999,-0) {};
# \draw (line0_gate17) edge[edgestyle] (line4_gate10);
# \node[phase] (line1_gate15) at (13.89999999999999,-1) {};
# \draw (line1_gate15) edge[edgestyle] (line4_gate10);
# \node[phase] (line2_gate16) at (13.89999999999999,-2) {};
# \draw (line2_gate16) edge[edgestyle] (line4_gate10);
# \node[phase] (line3_gate16) at (13.89999999999999,-3) {};
# \draw (line3_gate16) edge[edgestyle] (line4_gate10);
# \draw (line4_gate8) edge[edgestyle] (line4_gate9);
# \draw (line0_gate16) edge[edgestyle] (line0_gate17);
# \draw (line1_gate14) edge[edgestyle] (line1_gate15);
# \draw (line2_gate15) edge[edgestyle] (line2_gate16);
# \draw (line3_gate15) edge[edgestyle] (line3_gate16);
# \node[none] (line5_gate7) at (14.549999999999988,-5) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line5_gate8) at (14.799999999999988,-5) {};
# \node[none] (line5_gate9) at (15.049999999999988,-5) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line5_gate7) rectangle ([yshift=-0.25cm]line5_gate9) node[pos=.5] {Y};
# \node[phase] (line0_gate18) at (14.799999999999988,-0) {};
# \draw (line0_gate18) edge[edgestyle] (line5_gate8);
# \node[phase] (line1_gate16) at (14.799999999999988,-1) {};
# \draw (line1_gate16) edge[edgestyle] (line5_gate8);
# \node[phase] (line2_gate17) at (14.799999999999988,-2) {};
# \draw (line2_gate17) edge[edgestyle] (line5_gate8);
# \node[phase] (line3_gate17) at (14.799999999999988,-3) {};
# \draw (line3_gate17) edge[edgestyle] (line5_gate8);
# \draw (line5_gate6) edge[edgestyle] (line5_gate7);
# \draw (line0_gate17) edge[edgestyle] (line0_gate18);
# \draw (line1_gate15) edge[edgestyle] (line1_gate16);
# \draw (line2_gate16) edge[edgestyle] (line2_gate17);
# \draw (line3_gate16) edge[edgestyle] (line3_gate17);
# \node[xstyle] (line6_gate6) at (15.349999999999987,-6) {};
# \draw[edgestyle] (line6_gate6.north)--(line6_gate6.south);
# \draw[edgestyle] (line6_gate6.west)--(line6_gate6.east);
# \node[phase] (line0_gate19) at (15.349999999999987,-0) {};
# \draw (line0_gate19) edge[edgestyle] (line6_gate6);
# \node[phase] (line1_gate17) at (15.349999999999987,-1) {};
# \draw (line1_gate17) edge[edgestyle] (line6_gate6);
# \node[phase] (line2_gate18) at (15.349999999999987,-2) {};
# \draw (line2_gate18) edge[edgestyle] (line6_gate6);
# \node[phase] (line3_gate18) at (15.349999999999987,-3) {};
# \draw (line3_gate18) edge[edgestyle] (line6_gate6);
# \draw (line6_gate5) edge[edgestyle] (line6_gate6);
# \draw (line0_gate18) edge[edgestyle] (line0_gate19);
# \draw (line1_gate16) edge[edgestyle] (line1_gate17);
# \draw (line2_gate17) edge[edgestyle] (line2_gate18);
# \draw (line3_gate17) edge[edgestyle] (line3_gate18);
# \node[xstyle] (line7_gate8) at (15.899999999999986,-7) {};
# \draw[edgestyle] (line7_gate8.north)--(line7_gate8.south);
# \draw[edgestyle] (line7_gate8.west)--(line7_gate8.east);
# \node[phase] (line0_gate20) at (15.899999999999986,-0) {};
# \draw (line0_gate20) edge[edgestyle] (line7_gate8);
# \node[phase] (line1_gate18) at (15.899999999999986,-1) {};
# \draw (line1_gate18) edge[edgestyle] (line7_gate8);
# \node[phase] (line2_gate19) at (15.899999999999986,-2) {};
# \draw (line2_gate19) edge[edgestyle] (line7_gate8);
# \node[phase] (line3_gate19) at (15.899999999999986,-3) {};
# \draw (line3_gate19) edge[edgestyle] (line7_gate8);
# \draw (line7_gate7) edge[edgestyle] (line7_gate8);
# \draw (line0_gate19) edge[edgestyle] (line0_gate20);
# \draw (line1_gate17) edge[edgestyle] (line1_gate18);
# \draw (line2_gate18) edge[edgestyle] (line2_gate19);
# \draw (line3_gate18) edge[edgestyle] (line3_gate19);
# \node[xstyle] (line0_gate21) at (16.44999999999999,-0) {};
# \draw[edgestyle] (line0_gate21.north)--(line0_gate21.south);
# \draw[edgestyle] (line0_gate21.west)--(line0_gate21.east);
# \draw (line0_gate20) edge[edgestyle] (line0_gate21);
# \node[xstyle] (line4_gate12) at (16.999999999999993,-4) {};
# \draw[edgestyle] (line4_gate12.north)--(line4_gate12.south);
# \draw[edgestyle] (line4_gate12.west)--(line4_gate12.east);
# \node[phase] (line0_gate22) at (16.999999999999993,-0) {};
# \draw (line0_gate22) edge[edgestyle] (line4_gate12);
# \node[phase] (line1_gate19) at (16.999999999999993,-1) {};
# \draw (line1_gate19) edge[edgestyle] (line4_gate12);
# \node[phase] (line2_gate20) at (16.999999999999993,-2) {};
# \draw (line2_gate20) edge[edgestyle] (line4_gate12);
# \node[phase] (line3_gate20) at (16.999999999999993,-3) {};
# \draw (line3_gate20) edge[edgestyle] (line4_gate12);
# \draw (line4_gate11) edge[edgestyle] (line4_gate12);
# \draw (line0_gate21) edge[edgestyle] (line0_gate22);
# \draw (line1_gate18) edge[edgestyle] (line1_gate19);
# \draw (line2_gate19) edge[edgestyle] (line2_gate20);
# \draw (line3_gate19) edge[edgestyle] (line3_gate20);
# \node[xstyle] (line5_gate10) at (17.549999999999997,-5) {};
# \draw[edgestyle] (line5_gate10.north)--(line5_gate10.south);
# \draw[edgestyle] (line5_gate10.west)--(line5_gate10.east);
# \node[phase] (line0_gate23) at (17.549999999999997,-0) {};
# \draw (line0_gate23) edge[edgestyle] (line5_gate10);
# \node[phase] (line1_gate20) at (17.549999999999997,-1) {};
# \draw (line1_gate20) edge[edgestyle] (line5_gate10);
# \node[phase] (line2_gate21) at (17.549999999999997,-2) {};
# \draw (line2_gate21) edge[edgestyle] (line5_gate10);
# \node[phase] (line3_gate21) at (17.549999999999997,-3) {};
# \draw (line3_gate21) edge[edgestyle] (line5_gate10);
# \draw (line5_gate9) edge[edgestyle] (line5_gate10);
# \draw (line0_gate22) edge[edgestyle] (line0_gate23);
# \draw (line1_gate19) edge[edgestyle] (line1_gate20);
# \draw (line2_gate20) edge[edgestyle] (line2_gate21);
# \draw (line3_gate20) edge[edgestyle] (line3_gate21);
# \node[none] (line6_gate7) at (18.2,-6) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line6_gate8) at (18.45,-6) {};
# \node[none] (line6_gate9) at (18.7,-6) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line6_gate7) rectangle ([yshift=-0.25cm]line6_gate9) node[pos=.5] {Y};
# \node[phase] (line0_gate24) at (18.45,-0) {};
# \draw (line0_gate24) edge[edgestyle] (line6_gate8);
# \node[phase] (line1_gate21) at (18.45,-1) {};
# \draw (line1_gate21) edge[edgestyle] (line6_gate8);
# \node[phase] (line2_gate22) at (18.45,-2) {};
# \draw (line2_gate22) edge[edgestyle] (line6_gate8);
# \node[phase] (line3_gate22) at (18.45,-3) {};
# \draw (line3_gate22) edge[edgestyle] (line6_gate8);
# \draw (line6_gate6) edge[edgestyle] (line6_gate7);
# \draw (line0_gate23) edge[edgestyle] (line0_gate24);
# \draw (line1_gate20) edge[edgestyle] (line1_gate21);
# \draw (line2_gate21) edge[edgestyle] (line2_gate22);
# \draw (line3_gate21) edge[edgestyle] (line3_gate22);
# \node[none] (line7_gate9) at (19.099999999999998,-7) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line7_gate10) at (19.349999999999998,-7) {};
# \node[none] (line7_gate11) at (19.599999999999998,-7) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line7_gate9) rectangle ([yshift=-0.25cm]line7_gate11) node[pos=.5] {Y};
# \node[phase] (line0_gate25) at (19.349999999999998,-0) {};
# \draw (line0_gate25) edge[edgestyle] (line7_gate10);
# \node[phase] (line1_gate22) at (19.349999999999998,-1) {};
# \draw (line1_gate22) edge[edgestyle] (line7_gate10);
# \node[phase] (line2_gate23) at (19.349999999999998,-2) {};
# \draw (line2_gate23) edge[edgestyle] (line7_gate10);
# \node[phase] (line3_gate23) at (19.349999999999998,-3) {};
# \draw (line3_gate23) edge[edgestyle] (line7_gate10);
# \draw (line7_gate8) edge[edgestyle] (line7_gate9);
# \draw (line0_gate24) edge[edgestyle] (line0_gate25);
# \draw (line1_gate21) edge[edgestyle] (line1_gate22);
# \draw (line2_gate22) edge[edgestyle] (line2_gate23);
# \draw (line3_gate22) edge[edgestyle] (line3_gate23);
# \node[xstyle] (line1_gate23) at (19.9,-1) {};
# \draw[edgestyle] (line1_gate23.north)--(line1_gate23.south);
# \draw[edgestyle] (line1_gate23.west)--(line1_gate23.east);
# \draw (line1_gate22) edge[edgestyle] (line1_gate23);
# \node[xstyle] (line4_gate13) at (20.450000000000003,-4) {};
# \draw[edgestyle] (line4_gate13.north)--(line4_gate13.south);
# \draw[edgestyle] (line4_gate13.west)--(line4_gate13.east);
# \node[phase] (line0_gate26) at (20.450000000000003,-0) {};
# \draw (line0_gate26) edge[edgestyle] (line4_gate13);
# \node[phase] (line1_gate24) at (20.450000000000003,-1) {};
# \draw (line1_gate24) edge[edgestyle] (line4_gate13);
# \node[phase] (line2_gate24) at (20.450000000000003,-2) {};
# \draw (line2_gate24) edge[edgestyle] (line4_gate13);
# \node[phase] (line3_gate24) at (20.450000000000003,-3) {};
# \draw (line3_gate24) edge[edgestyle] (line4_gate13);
# \draw (line4_gate12) edge[edgestyle] (line4_gate13);
# \draw (line0_gate25) edge[edgestyle] (line0_gate26);
# \draw (line1_gate23) edge[edgestyle] (line1_gate24);
# \draw (line2_gate23) edge[edgestyle] (line2_gate24);
# \draw (line3_gate23) edge[edgestyle] (line3_gate24);
# \node[none] (line5_gate11) at (21.100000000000005,-5) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line5_gate12) at (21.350000000000005,-5) {};
# \node[none] (line5_gate13) at (21.600000000000005,-5) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line5_gate11) rectangle ([yshift=-0.25cm]line5_gate13) node[pos=.5] {Y};
# \node[phase] (line0_gate27) at (21.350000000000005,-0) {};
# \draw (line0_gate27) edge[edgestyle] (line5_gate12);
# \node[phase] (line1_gate25) at (21.350000000000005,-1) {};
# \draw (line1_gate25) edge[edgestyle] (line5_gate12);
# \node[phase] (line2_gate25) at (21.350000000000005,-2) {};
# \draw (line2_gate25) edge[edgestyle] (line5_gate12);
# \node[phase] (line3_gate25) at (21.350000000000005,-3) {};
# \draw (line3_gate25) edge[edgestyle] (line5_gate12);
# \draw (line5_gate10) edge[edgestyle] (line5_gate11);
# \draw (line0_gate26) edge[edgestyle] (line0_gate27);
# \draw (line1_gate24) edge[edgestyle] (line1_gate25);
# \draw (line2_gate24) edge[edgestyle] (line2_gate25);
# \draw (line3_gate24) edge[edgestyle] (line3_gate25);
# \node[none] (line6_gate10) at (22.000000000000004,-6) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line6_gate11) at (22.250000000000004,-6) {};
# \node[none] (line6_gate12) at (22.500000000000004,-6) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line6_gate10) rectangle ([yshift=-0.25cm]line6_gate12) node[pos=.5] {Y};
# \node[phase] (line0_gate28) at (22.250000000000004,-0) {};
# \draw (line0_gate28) edge[edgestyle] (line6_gate11);
# \node[phase] (line1_gate26) at (22.250000000000004,-1) {};
# \draw (line1_gate26) edge[edgestyle] (line6_gate11);
# \node[phase] (line2_gate26) at (22.250000000000004,-2) {};
# \draw (line2_gate26) edge[edgestyle] (line6_gate11);
# \node[phase] (line3_gate26) at (22.250000000000004,-3) {};
# \draw (line3_gate26) edge[edgestyle] (line6_gate11);
# \draw (line6_gate9) edge[edgestyle] (line6_gate10);
# \draw (line0_gate27) edge[edgestyle] (line0_gate28);
# \draw (line1_gate25) edge[edgestyle] (line1_gate26);
# \draw (line2_gate25) edge[edgestyle] (line2_gate26);
# \draw (line3_gate25) edge[edgestyle] (line3_gate26);
# \node[xstyle] (line7_gate12) at (22.800000000000004,-7) {};
# \draw[edgestyle] (line7_gate12.north)--(line7_gate12.south);
# \draw[edgestyle] (line7_gate12.west)--(line7_gate12.east);
# \node[phase] (line0_gate29) at (22.800000000000004,-0) {};
# \draw (line0_gate29) edge[edgestyle] (line7_gate12);
# \node[phase] (line1_gate27) at (22.800000000000004,-1) {};
# \draw (line1_gate27) edge[edgestyle] (line7_gate12);
# \node[phase] (line2_gate27) at (22.800000000000004,-2) {};
# \draw (line2_gate27) edge[edgestyle] (line7_gate12);
# \node[phase] (line3_gate27) at (22.800000000000004,-3) {};
# \draw (line3_gate27) edge[edgestyle] (line7_gate12);
# \draw (line7_gate11) edge[edgestyle] (line7_gate12);
# \draw (line0_gate28) edge[edgestyle] (line0_gate29);
# \draw (line1_gate26) edge[edgestyle] (line1_gate27);
# \draw (line2_gate26) edge[edgestyle] (line2_gate27);
# \draw (line3_gate26) edge[edgestyle] (line3_gate27);
# \node[xstyle] (line0_gate30) at (23.35000000000001,-0) {};
# \draw[edgestyle] (line0_gate30.north)--(line0_gate30.south);
# \draw[edgestyle] (line0_gate30.west)--(line0_gate30.east);
# \draw (line0_gate29) edge[edgestyle] (line0_gate30);
# \node[phase] (line4_gate14) at (24.00000000000001,-4) {};
# \node[phase] (line0_gate31) at (24.00000000000001,-0) {};
# \draw (line0_gate31) edge[edgestyle] (line4_gate14);
# \node[phase] (line1_gate28) at (24.00000000000001,-1) {};
# \draw (line1_gate28) edge[edgestyle] (line4_gate14);
# \node[phase] (line2_gate28) at (24.00000000000001,-2) {};
# \draw (line2_gate28) edge[edgestyle] (line4_gate14);
# \node[phase] (line3_gate28) at (24.00000000000001,-3) {};
# \draw (line3_gate28) edge[edgestyle] (line4_gate14);
# \draw (line4_gate13) edge[edgestyle] (line4_gate14);
# \draw (line0_gate30) edge[edgestyle] (line0_gate31);
# \draw (line1_gate27) edge[edgestyle] (line1_gate28);
# \draw (line2_gate27) edge[edgestyle] (line2_gate28);
# \draw (line3_gate27) edge[edgestyle] (line3_gate28);
# \node[phase] (line6_gate13) at (24.90000000000001,-6) {};
# \node[phase] (line0_gate32) at (24.90000000000001,-0) {};
# \draw (line0_gate32) edge[edgestyle] (line6_gate13);
# \node[phase] (line1_gate29) at (24.90000000000001,-1) {};
# \draw (line1_gate29) edge[edgestyle] (line6_gate13);
# \node[phase] (line2_gate29) at (24.90000000000001,-2) {};
# \draw (line2_gate29) edge[edgestyle] (line6_gate13);
# \node[phase] (line3_gate29) at (24.90000000000001,-3) {};
# \draw (line3_gate29) edge[edgestyle] (line6_gate13);
# \draw (line6_gate12) edge[edgestyle] (line6_gate13);
# \draw (line0_gate31) edge[edgestyle] (line0_gate32);
# \draw (line1_gate28) edge[edgestyle] (line1_gate29);
# \draw (line2_gate28) edge[edgestyle] (line2_gate29);
# \draw (line3_gate28) edge[edgestyle] (line3_gate29);
# \node[xstyle] (line2_gate30) at (25.70000000000001,-2) {};
# \draw[edgestyle] (line2_gate30.north)--(line2_gate30.south);
# \draw[edgestyle] (line2_gate30.west)--(line2_gate30.east);
# \draw (line2_gate29) edge[edgestyle] (line2_gate30);
# \node[phase] (line4_gate15) at (26.350000000000012,-4) {};
# \node[phase] (line0_gate33) at (26.350000000000012,-0) {};
# \draw (line0_gate33) edge[edgestyle] (line4_gate15);
# \node[phase] (line1_gate30) at (26.350000000000012,-1) {};
# \draw (line1_gate30) edge[edgestyle] (line4_gate15);
# \node[phase] (line2_gate31) at (26.350000000000012,-2) {};
# \draw (line2_gate31) edge[edgestyle] (line4_gate15);
# \node[phase] (line3_gate30) at (26.350000000000012,-3) {};
# \draw (line3_gate30) edge[edgestyle] (line4_gate15);
# \draw (line4_gate14) edge[edgestyle] (line4_gate15);
# \draw (line0_gate32) edge[edgestyle] (line0_gate33);
# \draw (line1_gate29) edge[edgestyle] (line1_gate30);
# \draw (line2_gate30) edge[edgestyle] (line2_gate31);
# \draw (line3_gate29) edge[edgestyle] (line3_gate30);
# \node[phase] (line7_gate13) at (27.25000000000001,-7) {};
# \node[phase] (line0_gate34) at (27.25000000000001,-0) {};
# \draw (line0_gate34) edge[edgestyle] (line7_gate13);
# \node[phase] (line1_gate31) at (27.25000000000001,-1) {};
# \draw (line1_gate31) edge[edgestyle] (line7_gate13);
# \node[phase] (line2_gate32) at (27.25000000000001,-2) {};
# \draw (line2_gate32) edge[edgestyle] (line7_gate13);
# \node[phase] (line3_gate31) at (27.25000000000001,-3) {};
# \draw (line3_gate31) edge[edgestyle] (line7_gate13);
# \draw (line7_gate12) edge[edgestyle] (line7_gate13);
# \draw (line0_gate33) edge[edgestyle] (line0_gate34);
# \draw (line1_gate30) edge[edgestyle] (line1_gate31);
# \draw (line2_gate31) edge[edgestyle] (line2_gate32);
# \draw (line3_gate30) edge[edgestyle] (line3_gate31);
# \node[xstyle] (line0_gate35) at (28.05000000000001,-0) {};
# \draw[edgestyle] (line0_gate35.north)--(line0_gate35.south);
# \draw[edgestyle] (line0_gate35.west)--(line0_gate35.east);
# \draw (line0_gate34) edge[edgestyle] (line0_gate35);
# \node[phase] (line5_gate14) at (28.700000000000014,-5) {};
# \node[phase] (line0_gate36) at (28.700000000000014,-0) {};
# \draw (line0_gate36) edge[edgestyle] (line5_gate14);
# \node[phase] (line1_gate32) at (28.700000000000014,-1) {};
# \draw (line1_gate32) edge[edgestyle] (line5_gate14);
# \node[phase] (line2_gate33) at (28.700000000000014,-2) {};
# \draw (line2_gate33) edge[edgestyle] (line5_gate14);
# \node[phase] (line3_gate32) at (28.700000000000014,-3) {};
# \draw (line3_gate32) edge[edgestyle] (line5_gate14);
# \draw (line5_gate13) edge[edgestyle] (line5_gate14);
# \draw (line0_gate35) edge[edgestyle] (line0_gate36);
# \draw (line1_gate31) edge[edgestyle] (line1_gate32);
# \draw (line2_gate32) edge[edgestyle] (line2_gate33);
# \draw (line3_gate31) edge[edgestyle] (line3_gate32);
# \node[phase] (line6_gate14) at (29.600000000000012,-6) {};
# \node[phase] (line0_gate37) at (29.600000000000012,-0) {};
# \draw (line0_gate37) edge[edgestyle] (line6_gate14);
# \node[phase] (line1_gate33) at (29.600000000000012,-1) {};
# \draw (line1_gate33) edge[edgestyle] (line6_gate14);
# \node[phase] (line2_gate34) at (29.600000000000012,-2) {};
# \draw (line2_gate34) edge[edgestyle] (line6_gate14);
# \node[phase] (line3_gate33) at (29.600000000000012,-3) {};
# \draw (line3_gate33) edge[edgestyle] (line6_gate14);
# \draw (line6_gate13) edge[edgestyle] (line6_gate14);
# \draw (line0_gate36) edge[edgestyle] (line0_gate37);
# \draw (line1_gate32) edge[edgestyle] (line1_gate33);
# \draw (line2_gate33) edge[edgestyle] (line2_gate34);
# \draw (line3_gate32) edge[edgestyle] (line3_gate33);
# \node[xstyle] (line1_gate34) at (30.400000000000013,-1) {};
# \draw[edgestyle] (line1_gate34.north)--(line1_gate34.south);
# \draw[edgestyle] (line1_gate34.west)--(line1_gate34.east);
# \draw (line1_gate33) edge[edgestyle] (line1_gate34);
# \node[phase] (line5_gate15) at (31.050000000000015,-5) {};
# \node[phase] (line0_gate38) at (31.050000000000015,-0) {};
# \draw (line0_gate38) edge[edgestyle] (line5_gate15);
# \node[phase] (line1_gate35) at (31.050000000000015,-1) {};
# \draw (line1_gate35) edge[edgestyle] (line5_gate15);
# \node[phase] (line2_gate35) at (31.050000000000015,-2) {};
# \draw (line2_gate35) edge[edgestyle] (line5_gate15);
# \node[phase] (line3_gate34) at (31.050000000000015,-3) {};
# \draw (line3_gate34) edge[edgestyle] (line5_gate15);
# \draw (line5_gate14) edge[edgestyle] (line5_gate15);
# \draw (line0_gate37) edge[edgestyle] (line0_gate38);
# \draw (line1_gate34) edge[edgestyle] (line1_gate35);
# \draw (line2_gate34) edge[edgestyle] (line2_gate35);
# \draw (line3_gate33) edge[edgestyle] (line3_gate34);
# \node[phase] (line7_gate14) at (31.950000000000014,-7) {};
# \node[phase] (line0_gate39) at (31.950000000000014,-0) {};
# \draw (line0_gate39) edge[edgestyle] (line7_gate14);
# \node[phase] (line1_gate36) at (31.950000000000014,-1) {};
# \draw (line1_gate36) edge[edgestyle] (line7_gate14);
# \node[phase] (line2_gate36) at (31.950000000000014,-2) {};
# \draw (line2_gate36) edge[edgestyle] (line7_gate14);
# \node[phase] (line3_gate35) at (31.950000000000014,-3) {};
# \draw (line3_gate35) edge[edgestyle] (line7_gate14);
# \draw (line7_gate13) edge[edgestyle] (line7_gate14);
# \draw (line0_gate38) edge[edgestyle] (line0_gate39);
# \draw (line1_gate35) edge[edgestyle] (line1_gate36);
# \draw (line2_gate35) edge[edgestyle] (line2_gate36);
# \draw (line3_gate34) edge[edgestyle] (line3_gate35);
# \node[xstyle] (line0_gate40) at (32.750000000000014,-0) {};
# \draw[edgestyle] (line0_gate40.north)--(line0_gate40.south);
# \draw[edgestyle] (line0_gate40.west)--(line0_gate40.east);
# \draw (line0_gate39) edge[edgestyle] (line0_gate40);
# \node[phase] (line6_gate15) at (33.40000000000002,-6) {};
# \node[phase] (line0_gate41) at (33.40000000000002,-0) {};
# \draw (line0_gate41) edge[edgestyle] (line6_gate15);
# \node[phase] (line1_gate37) at (33.40000000000002,-1) {};
# \draw (line1_gate37) edge[edgestyle] (line6_gate15);
# \node[phase] (line2_gate37) at (33.40000000000002,-2) {};
# \draw (line2_gate37) edge[edgestyle] (line6_gate15);
# \node[phase] (line3_gate36) at (33.40000000000002,-3) {};
# \draw (line3_gate36) edge[edgestyle] (line6_gate15);
# \draw (line6_gate14) edge[edgestyle] (line6_gate15);
# \draw (line0_gate40) edge[edgestyle] (line0_gate41);
# \draw (line1_gate36) edge[edgestyle] (line1_gate37);
# \draw (line2_gate36) edge[edgestyle] (line2_gate37);
# \draw (line3_gate35) edge[edgestyle] (line3_gate36);
# \node[phase] (line7_gate15) at (34.300000000000026,-7) {};
# \node[phase] (line0_gate42) at (34.300000000000026,-0) {};
# \draw (line0_gate42) edge[edgestyle] (line7_gate15);
# \node[phase] (line1_gate38) at (34.300000000000026,-1) {};
# \draw (line1_gate38) edge[edgestyle] (line7_gate15);
# \node[phase] (line2_gate38) at (34.300000000000026,-2) {};
# \draw (line2_gate38) edge[edgestyle] (line7_gate15);
# \node[phase] (line3_gate37) at (34.300000000000026,-3) {};
# \draw (line3_gate37) edge[edgestyle] (line7_gate15);
# \draw (line7_gate14) edge[edgestyle] (line7_gate15);
# \draw (line0_gate41) edge[edgestyle] (line0_gate42);
# \draw (line1_gate37) edge[edgestyle] (line1_gate38);
# \draw (line2_gate37) edge[edgestyle] (line2_gate38);
# \draw (line3_gate36) edge[edgestyle] (line3_gate37);
# \node[xstyle] (line0_gate43) at (35.10000000000003,-0) {};
# \draw[edgestyle] (line0_gate43.north)--(line0_gate43.south);
# \draw[edgestyle] (line0_gate43.west)--(line0_gate43.east);
# \draw (line0_gate42) edge[edgestyle] (line0_gate43);
# \node[none] (line0_gate44) at (35.650000000000034,-0) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line0_gate45) at (35.900000000000034,-0) {};
# \node[none] (line0_gate46) at (36.150000000000034,-0) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line0_gate44) rectangle ([yshift=-0.25cm]line0_gate46) node[pos=.5] {H};
# \draw (line0_gate43) edge[edgestyle] (line0_gate44);
# \node[none] (line0_gate47) at (36.55000000000003,-0) {};
# \draw ([yshift=0.15cm]line0_gate47.center) edge [edgestyle] ([yshift=-0.15cm]line0_gate47.center);
# \draw (line0_gate46) edge[edgestyle] (line0_gate47);
# \node[xstyle] (line1_gate39) at (35.10000000000003,-1) {};
# \draw[edgestyle] (line1_gate39.north)--(line1_gate39.south);
# \draw[edgestyle] (line1_gate39.west)--(line1_gate39.east);
# \draw (line1_gate38) edge[edgestyle] (line1_gate39);
# \node[none] (line1_gate40) at (35.650000000000034,-1) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line1_gate41) at (35.900000000000034,-1) {};
# \node[none] (line1_gate42) at (36.150000000000034,-1) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line1_gate40) rectangle ([yshift=-0.25cm]line1_gate42) node[pos=.5] {H};
# \draw (line1_gate39) edge[edgestyle] (line1_gate40);
# \node[none] (line1_gate43) at (36.55000000000003,-1) {};
# \draw ([yshift=0.15cm]line1_gate43.center) edge [edgestyle] ([yshift=-0.15cm]line1_gate43.center);
# \draw (line1_gate42) edge[edgestyle] (line1_gate43);
# \node[xstyle] (line2_gate39) at (35.10000000000003,-2) {};
# \draw[edgestyle] (line2_gate39.north)--(line2_gate39.south);
# \draw[edgestyle] (line2_gate39.west)--(line2_gate39.east);
# \draw (line2_gate38) edge[edgestyle] (line2_gate39);
# \node[none] (line2_gate40) at (35.650000000000034,-2) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line2_gate41) at (35.900000000000034,-2) {};
# \node[none] (line2_gate42) at (36.150000000000034,-2) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line2_gate40) rectangle ([yshift=-0.25cm]line2_gate42) node[pos=.5] {H};
# \draw (line2_gate39) edge[edgestyle] (line2_gate40);
# \node[none] (line2_gate43) at (36.55000000000003,-2) {};
# \draw ([yshift=0.15cm]line2_gate43.center) edge [edgestyle] ([yshift=-0.15cm]line2_gate43.center);
# \draw (line2_gate42) edge[edgestyle] (line2_gate43);
# \node[none] (line3_gate38) at (35.10000000000003,-3) {};
# \node[none,minimum height=0.5cm,outer sep=0] (line3_gate39) at (35.35000000000003,-3) {};
# \node[none] (line3_gate40) at (35.60000000000003,-3) {};
# \draw[operator,edgestyle,outer sep=0.5cm] ([yshift=0.25cm]line3_gate38) rectangle ([yshift=-0.25cm]line3_gate40) node[pos=.5] {H};
# \draw (line3_gate37) edge[edgestyle] (line3_gate38);
# \node[none] (line3_gate41) at (36.00000000000003,-3) {};
# \draw ([yshift=0.15cm]line3_gate41.center) edge [edgestyle] ([yshift=-0.15cm]line3_gate41.center);
# \draw (line3_gate40) edge[edgestyle] (line3_gate41);
# \node[none] (line4_gate16) at (35.10000000000003,-4) {};
# \draw ([yshift=0.15cm]line4_gate16.center) edge [edgestyle] ([yshift=-0.15cm]line4_gate16.center);
# \draw (line4_gate15) edge[edgestyle] (line4_gate16);
# \node[none] (line5_gate16) at (35.10000000000003,-5) {};
# \draw ([yshift=0.15cm]line5_gate16.center) edge [edgestyle] ([yshift=-0.15cm]line5_gate16.center);
# \draw (line5_gate15) edge[edgestyle] (line5_gate16);
# \node[none] (line6_gate16) at (35.10000000000003,-6) {};
# \draw ([yshift=0.15cm]line6_gate16.center) edge [edgestyle] ([yshift=-0.15cm]line6_gate16.center);
# \draw (line6_gate15) edge[edgestyle] (line6_gate16);
# \node[none] (line7_gate16) at (35.10000000000003,-7) {};
# \draw ([yshift=0.15cm]line7_gate16.center) edge [edgestyle] ([yshift=-0.15cm]line7_gate16.center);
# \draw (line7_gate15) edge[edgestyle] (line7_gate16);
#
# \end{tikzpicture}
# \end{document}
